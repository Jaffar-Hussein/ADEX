# %% [markdown]
# # **Interspike interval for variation of current $I$**

# %%
from brian2 import *
import matplotlib.pyplot as plt
import numpy

# %%
# The spike intervals varibles for plotting 
isi05 = []
isi06 = []
isi07 = []
isi08 = []
isi09 = []
isi1 = []
isi2 =[]
isi25=[]

eqs = eqs = """
    dvm/dt = (g_l*(e_l - vm) + g_l*d_t*exp((vm-v_t)/d_t) + i_stim - w)/c_m : volt (unless refractory)
    dw/dt  = (a*(vm - e_l) - w)/tau_w : amp
    """

# %% [markdown]
# ### $0.05nA$

# %%
parameters = {
    "c_m": 200 * pF,
    "g_l": 10.*nS,
    "e_l": -65.*mV,
    "v_t": -55.*mV,
    "d_t": 5.0*mV,
    "a": 2.0 * nS,
    "tau_w": 500.0*ms,
    "b": 10.0*pA,
    "v_r": -52*mV,
    "i_stim": .05*nA,
}

# %%
neuron = NeuronGroup(
    1,
    model=eqs,
    threshold="vm > -40.*mV", 
    reset="vm = v_r; w += b",
    refractory='5*ms',
    method="euler",
    namespace=parameters,
)
neuron.vm = parameters["e_l"]
neuron.w = 0
states = StateMonitor(neuron, ["vm", "w"], record=True, when="thresholds")
defaultclock.dt = 0.1 * ms
train = SpikeMonitor(neuron,record=True)
run(4000 * ms)

# clip membrane voltages to threshold (0 mV)
vms = np.clip(states[0].vm / mV, a_min=None, a_max=0)
plt.plot(states[0].t / ms, vms)

plt.xlabel('Time in (ms)')
plt.ylabel('Voltage in (mV)')
# print(train.spike_trains())
# The interspike interval
difference  = numpy.diff(train.spike_trains()[0])
# Adding the ISI to a list for plotting
isi05.append(difference)
# print(difference)
# print(isi05)
plt.show()

# %% [markdown]
# ### $0.06nA$

# %%
parameters = {
    "c_m": 200 * pF,
    "g_l": 10.*nS,
    "e_l": -65.*mV,
    "v_t": -55.*mV,
    "d_t": 5.0*mV,
    "a": 2.0 * nS,
    "tau_w": 500.0*ms,
    "b": 10.0*pA,
    "v_r": -52*mV,
    "i_stim": .06*nA,
}

# %%
neuron = NeuronGroup(
    1,
    model=eqs,
    threshold="vm > -40.*mV", 
    reset="vm = v_r; w += b",
    refractory='5*ms',
    method="euler",
    namespace=parameters,
)
neuron.vm = parameters["e_l"]
neuron.w = 0
states = StateMonitor(neuron, ["vm", "w"], record=True, when="thresholds")
defaultclock.dt = 0.1 * ms
train = SpikeMonitor(neuron,record=True)
run(4000 * ms)

# clip membrane voltages to threshold (0 mV)
vms = np.clip(states[0].vm / mV, a_min=None, a_max=0)
plt.plot(states[0].t / ms, vms)

plt.xlabel('Time in (ms)')
plt.ylabel('Voltage in (mV)')
# print(train.spike_trains())
# The interspike interval
difference  = numpy.diff(train.spike_trains()[0])
# Adding the ISI to a list for plotting
isi06.append(difference)
# print(difference)
# print(isi05)
plt.show()

# %% [markdown]
# ### $0.07nA$

# %%
parameters = {
    "c_m": 200 * pF,
    "g_l": 10.*nS,
    "e_l": -65.*mV,
    "v_t": -55.*mV,
    "d_t": 5.0*mV,
    "a": 2.0 * nS,
    "tau_w": 500.0*ms,
    "b": 10.0*pA,
    "v_r": -52*mV,
    "i_stim": .07*nA,
}

# %%
neuron = NeuronGroup(
    1,
    model=eqs,
    threshold="vm > -40.*mV", 
    reset="vm = v_r; w += b",
    refractory='5*ms',
    method="euler",
    namespace=parameters,
)
neuron.vm = parameters["e_l"]
neuron.w = 0
states = StateMonitor(neuron, ["vm", "w"], record=True, when="thresholds")
defaultclock.dt = 0.1 * ms
train = SpikeMonitor(neuron,record=True)
run(4000 * ms)

# clip membrane voltages to threshold (0 mV)
vms = np.clip(states[0].vm / mV, a_min=None, a_max=0)
plt.plot(states[0].t / ms, vms)

plt.xlabel('Time in (ms)')
plt.ylabel('Voltage in (mV)')
# print(train.spike_trains())
# The interspike interval
difference  = numpy.diff(train.spike_trains()[0])
# Adding the ISI to a list for plotting
isi07.append(difference)
# print(difference)
print(isi07)
plt.show()
# Out:
# [array([34. , 49.7]) * msecond]

# %% [markdown]
# ### $0.08nA$

# %%
parameters = {
    "c_m": 200 * pF,
    "g_l": 10.*nS,
    "e_l": -65.*mV,
    "v_t": -55.*mV,
    "d_t": 5.0*mV,
    "a": 2.0 * nS,
    "tau_w": 500.0*ms,
    "b": 10.0*pA,
    "v_r": -52*mV,
    "i_stim": .08*nA,
}

# %%
neuron = NeuronGroup(
    1,
    model=eqs,
    threshold="vm > -40.*mV", 
    reset="vm = v_r; w += b",
    refractory='5*ms',
    method="euler",
    namespace=parameters,
)
neuron.vm = parameters["e_l"]
neuron.w = 0
states = StateMonitor(neuron, ["vm", "w"], record=True, when="thresholds")
defaultclock.dt = 0.1 * ms
train = SpikeMonitor(neuron,record=True)
run(4000 * ms)

# clip membrane voltages to threshold (0 mV)
vms = np.clip(states[0].vm / mV, a_min=None, a_max=0)
plt.plot(states[0].t / ms, vms)

plt.xlabel('Time in (ms)')
plt.ylabel('Voltage in (mV)')
# print(train.spike_trains())
# The interspike interval
difference  = numpy.diff(train.spike_trains()[0])
# Adding the ISI to a list for plotting
isi08.append(difference)
# print(difference)
# print(isi07)
plt.show()

# %% [markdown]
# ### $0.09nA$

# %%
parameters = {
    "c_m": 200 * pF,
    "g_l": 10.*nS,
    "e_l": -65.*mV,
    "v_t": -55.*mV,
    "d_t": 5.0*mV,
    "a": 2.0 * nS,
    "tau_w": 500.0*ms,
    "b": 10.0*pA,
    "v_r": -52*mV,
    "i_stim": .09*nA,
}

# %%
neuron = NeuronGroup(
    1,
    model=eqs,
    threshold="vm > -40.*mV", 
    reset="vm = v_r; w += b",
    refractory='5*ms',
    method="euler",
    namespace=parameters,
)
neuron.vm = parameters["e_l"]
neuron.w = 0
states = StateMonitor(neuron, ["vm", "w"], record=True, when="thresholds")
defaultclock.dt = 0.1 * ms
train = SpikeMonitor(neuron,record=True)
run(4000 * ms)

# clip membrane voltages to threshold (0 mV)
vms = np.clip(states[0].vm / mV, a_min=None, a_max=0)
plt.plot(states[0].t / ms, vms)

plt.xlabel('Time in (ms)')
plt.ylabel('Voltage in (mV)')
# print(train.spike_trains())
# The interspike interval
difference  = numpy.diff(train.spike_trains()[0])
# Adding the ISI to a list for plotting
isi09.append(difference)
# print(difference)
# print(isi07)
plt.show()

# %% [markdown]
# ### $0.1nA$

# %%
parameters = {
    "c_m": 200 * pF,
    "g_l": 10.*nS,
    "e_l": -65.*mV,
    "v_t": -55.*mV,
    "d_t": 5.0*mV,
    "a": 2.0 * nS,
    "tau_w": 500.0*ms,
    "b": 10.0*pA,
    "v_r": -52*mV,
    "i_stim": .1*nA,
}

# %%
neuron = NeuronGroup(
    1,
    model=eqs,
    threshold="vm > -40.*mV", 
    reset="vm = v_r; w += b",
    refractory='5*ms',
    method="euler",
    namespace=parameters,
)
neuron.vm = parameters["e_l"]
neuron.w = 0
states = StateMonitor(neuron, ["vm", "w"], record=True, when="thresholds")
defaultclock.dt = 0.1 * ms
train = SpikeMonitor(neuron,record=True)
run(4000 * ms)

# clip membrane voltages to threshold (0 mV)
vms = np.clip(states[0].vm / mV, a_min=None, a_max=0)
plt.plot(states[0].t / ms, vms)

plt.xlabel('Time in (ms)')
plt.ylabel('Voltage in (mV)')
# print(train.spike_trains())
# The interspike interval
difference  = numpy.diff(train.spike_trains()[0])
# Adding the ISI to a list for plotting
isi1.append(difference)
# print(difference)
# print(isi07)
plt.show()

# %% [markdown]
# ### $0.2nA$

# %%
parameters = {
    "c_m": 200 * pF,
    "g_l": 10.*nS,
    "e_l": -65.*mV,
    "v_t": -55.*mV,
    "d_t": 5.0*mV,
    "a": 2.0 * nS,
    "tau_w": 500.0*ms,
    "b": 10.0*pA,
    "v_r": -52*mV,
    "i_stim": .2*nA,
}

# %%
neuron = NeuronGroup(
    1,
    model=eqs,
    threshold="vm > -40.*mV", 
    reset="vm = v_r; w += b",
    refractory='5*ms',
    method="euler",
    namespace=parameters,
)
neuron.vm = parameters["e_l"]
neuron.w = 0
states = StateMonitor(neuron, ["vm", "w"], record=True, when="thresholds")
defaultclock.dt = 0.1 * ms
train = SpikeMonitor(neuron,record=True)
run(4000 * ms)

# clip membrane voltages to threshold (0 mV)
vms = np.clip(states[0].vm / mV, a_min=None, a_max=0)
plt.plot(states[0].t / ms, vms)

plt.xlabel('Time in (ms)')
plt.ylabel('Voltage in (mV)')
# print(train.spike_trains())
# The interspike interval
difference  = numpy.diff(train.spike_trains()[0])
# Adding the ISI to a list for plotting
isi2.append(difference)
# print(difference)
# print(isi07)
plt.show()

# %% [markdown]
# ### $0.25nA$

# %%
parameters = {
    "c_m": 200 * pF,
    "g_l": 10.*nS,
    "e_l": -65.*mV,
    "v_t": -55.*mV,
    "d_t": 5.0*mV,
    "a": 2.0 * nS,
    "tau_w": 500.0*ms,
    "b": 10.0*pA,
    "v_r": -52*mV,
    "i_stim": .25*nA,
}

# %%
neuron = NeuronGroup(
    1,
    model=eqs,
    threshold="vm > -40.*mV", 
    reset="vm = v_r; w += b",
    refractory='5*ms',
    method="euler",
    namespace=parameters,
)
neuron.vm = parameters["e_l"]
neuron.w = 0
states = StateMonitor(neuron, ["vm", "w"], record=True, when="thresholds")
defaultclock.dt = 0.1 * ms
train = SpikeMonitor(neuron,record=True)
run(4000 * ms)

# clip membrane voltages to threshold (0 mV)
vms = np.clip(states[0].vm / mV, a_min=None, a_max=0)
plt.plot(states[0].t / ms, vms)

plt.xlabel('Time in (ms)')
plt.ylabel('Voltage in (mV)')
# print(train.spike_trains())
# The interspike interval
difference  = numpy.diff(train.spike_trains()[0])
# Adding the ISI to a list for plotting
isi25.append(difference)
# print(difference)
# print(isi07)
plt.show()

# %% [markdown]
# # **PLOT OF THE INTERSPIKE DIFFERENCE**
